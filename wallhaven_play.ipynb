# %%
import requests
from call_retrievers import get_wallhaven_photos

# %%
key = 't7Jx4fJDMjTyIdApWsmAxx5KDmeBskgj'
tag = 'nature'

response = requests.get(f'https://wallhaven.cc/api/v1/search?apikey={key}&q={tag}')

response.json()
# Out:
# {'data': [{'id': 'gpoe2d',
#    'url': 'https://wallhaven.cc/w/gpoe2d',
#    'short_url': 'https://whvn.cc/gpoe2d',
#    'views': 6,
#    'favorites': 3,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1500,
#    'dimension_y': 1000,
#    'resolution': '1500x1000',
#    'ratio': '1.5',
#    'file_size': 419876,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 16:36:50',
#    'colors': ['#cccccc', '#999999', '#0099cc', '#e7d8b1', '#abbcda'],
#    'path': 'https://w.wallhaven.cc/full/gp/wallhaven-gpoe2d.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/gp/gpoe2d.jpg',
#     'original': 'https://th.wallhaven.cc/orig/gp/gpoe2d.jpg',
#     'small': 'https://th.wallhaven.cc/small/gp/gpoe2d.jpg'}},
#   {'id': 'jxmzvy',
#    'url': 'https://wallhaven.cc/w/jxmzvy',
#    'short_url': 'https://whvn.cc/jxmzvy',
#    'views': 5,
#    'favorites': 5,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2996,
#    'dimension_y': 1876,
#    'resolution': '2996x1876',
#    'ratio': '1.6',
#    'file_size': 2209803,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 16:36:50',
#    'colors': ['#66cccc', '#0099cc', '#abbcda', '#ea4c88', '#cccccc'],
#    'path': 'https://w.wallhaven.cc/full/jx/wallhaven-jxmzvy.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/jx/jxmzvy.jpg',
#     'original': 'https://th.wallhaven.cc/orig/jx/jxmzvy.jpg',
#     'small': 'https://th.wallhaven.cc/small/jx/jxmzvy.jpg'}},
#   {'id': 'd6l7el',
#    'url': 'https://wallhaven.cc/w/d6l7el',
#    'short_url': 'https://whvn.cc/d6l7el',
#    'views': 15,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 6144,
#    'dimension_y': 3456,
#    'resolution': '6144x3456',
#    'ratio': '1.78',
#    'file_size': 14729796,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 16:05:26',
#    'colors': ['#424153', '#663399', '#000000', '#333399', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/d6/wallhaven-d6l7el.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/d6/d6l7el.jpg',
#     'original': 'https://th.wallhaven.cc/orig/d6/d6l7el.jpg',
#     'small': 'https://th.wallhaven.cc/small/d6/d6l7el.jpg'}},
#   {'id': 'qz1ygq',
#    'url': 'https://wallhaven.cc/w/qz1ygq',
#    'short_url': 'https://whvn.cc/qz1ygq',
#    'views': 11,
#    'favorites': 3,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 5120,
#    'dimension_y': 2880,
#    'resolution': '5120x2880',
#    'ratio': '1.78',
#    'file_size': 10428473,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:59:33',
#    'colors': ['#0066cc', '#000000', '#424153', '#333399', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/qz/wallhaven-qz1ygq.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/qz/qz1ygq.jpg',
#     'original': 'https://th.wallhaven.cc/orig/qz/qz1ygq.jpg',
#     'small': 'https://th.wallhaven.cc/small/qz/qz1ygq.jpg'}},
#   {'id': '6dvr2w',
#    'url': 'https://wallhaven.cc/w/6dvr2w',
#    'short_url': 'https://whvn.cc/6dvr2w',
#    'views': 5,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 6144,
#    'dimension_y': 3456,
#    'resolution': '6144x3456',
#    'ratio': '1.78',
#    'file_size': 10911800,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#999999', '#abbcda', '#cccccc', '#0099cc'],
#    'path': 'https://w.wallhaven.cc/full/6d/wallhaven-6dvr2w.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/6d/6dvr2w.jpg',
#     'original': 'https://th.wallhaven.cc/orig/6d/6dvr2w.jpg',
#     'small': 'https://th.wallhaven.cc/small/6d/6dvr2w.jpg'}},
#   {'id': 'm3xkwy',
#    'url': 'https://wallhaven.cc/w/m3xkwy',
#    'short_url': 'https://whvn.cc/m3xkwy',
#    'views': 10,
#    'favorites': 6,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 8838,
#    'dimension_y': 4972,
#    'resolution': '8838x4972',
#    'ratio': '1.78',
#    'file_size': 15420648,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#333399', '#000000', '#336600', '#0066cc'],
#    'path': 'https://w.wallhaven.cc/full/m3/wallhaven-m3xkwy.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/m3/m3xkwy.jpg',
#     'original': 'https://th.wallhaven.cc/orig/m3/m3xkwy.jpg',
#     'small': 'https://th.wallhaven.cc/small/m3/m3xkwy.jpg'}},
#   {'id': 'p9qdjm',
#    'url': 'https://wallhaven.cc/w/p9qdjm',
#    'short_url': 'https://whvn.cc/p9qdjm',
#    'views': 12,
#    'favorites': 8,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 8256,
#    'dimension_y': 4818,
#    'resolution': '8256x4818',
#    'ratio': '1.71',
#    'file_size': 16043344,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#996633', '#0066cc', '#ff6600', '#000000'],
#    'path': 'https://w.wallhaven.cc/full/p9/wallhaven-p9qdjm.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/p9/p9qdjm.jpg',
#     'original': 'https://th.wallhaven.cc/orig/p9/p9qdjm.jpg',
#     'small': 'https://th.wallhaven.cc/small/p9/p9qdjm.jpg'}},
#   {'id': '7py5we',
#    'url': 'https://wallhaven.cc/w/7py5we',
#    'short_url': 'https://whvn.cc/7py5we',
#    'views': 15,
#    'favorites': 8,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 6048,
#    'dimension_y': 3590,
#    'resolution': '6048x3590',
#    'ratio': '1.68',
#    'file_size': 14474225,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#000000', '#333399', '#999999', '#663399'],
#    'path': 'https://w.wallhaven.cc/full/7p/wallhaven-7py5we.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/7p/7py5we.jpg',
#     'original': 'https://th.wallhaven.cc/orig/7p/7py5we.jpg',
#     'small': 'https://th.wallhaven.cc/small/7p/7py5we.jpg'}},
#   {'id': 'exjmer',
#    'url': 'https://wallhaven.cc/w/exjmer',
#    'short_url': 'https://whvn.cc/exjmer',
#    'views': 9,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 11574,
#    'dimension_y': 6000,
#    'resolution': '11574x6000',
#    'ratio': '1.93',
#    'file_size': 16333913,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#000000', '#999999', '#77cc33', '#663399'],
#    'path': 'https://w.wallhaven.cc/full/ex/wallhaven-exjmer.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/ex/exjmer.jpg',
#     'original': 'https://th.wallhaven.cc/orig/ex/exjmer.jpg',
#     'small': 'https://th.wallhaven.cc/small/ex/exjmer.jpg'}},
#   {'id': 'd6l75j',
#    'url': 'https://wallhaven.cc/w/d6l75j',
#    'short_url': 'https://whvn.cc/d6l75j',
#    'views': 135,
#    'favorites': 9,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 2000,
#    'dimension_y': 1516,
#    'resolution': '2000x1516',
#    'ratio': '1.32',
#    'file_size': 654578,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 11:07:06',
#    'colors': ['#999999', '#424153', '#996633', '#cccccc', '#000000'],
#    'path': 'https://w.wallhaven.cc/full/d6/wallhaven-d6l75j.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/d6/d6l75j.jpg',
#     'original': 'https://th.wallhaven.cc/orig/d6/d6l75j.jpg',
#     'small': 'https://th.wallhaven.cc/small/d6/d6l75j.jpg'}},
#   {'id': 'jxmz9m',
#    'url': 'https://wallhaven.cc/w/jxmz9m',
#    'short_url': 'https://whvn.cc/jxmz9m',
#    'views': 244,
#    'favorites': 8,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 853,
#    'dimension_y': 1280,
#    'resolution': '853x1280',
#    'ratio': '0.67',
#    'file_size': 368574,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 10:36:25',
#    'colors': ['#cccccc', '#999999', '#424153', '#996633', '#ffffff'],
#    'path': 'https://w.wallhaven.cc/full/jx/wallhaven-jxmz9m.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/jx/jxmz9m.jpg',
#     'original': 'https://th.wallhaven.cc/orig/jx/jxmz9m.jpg',
#     'small': 'https://th.wallhaven.cc/small/jx/jxmz9m.jpg'}},
#   {'id': 'vqw6xl',
#    'url': 'https://wallhaven.cc/w/vqw6xl',
#    'short_url': 'https://whvn.cc/vqw6xl',
#    'views': 76,
#    'favorites': 1,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 1920,
#    'dimension_y': 1080,
#    'resolution': '1920x1080',
#    'ratio': '1.78',
#    'file_size': 2523977,
#    'file_type': 'image/png',
#    'created_at': '2025-02-17 10:16:31',
#    'colors': ['#000000', '#663399', '#424153', '#333399', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/vq/wallhaven-vqw6xl.png',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/vq/vqw6xl.jpg',
#     'original': 'https://th.wallhaven.cc/orig/vq/vqw6xl.jpg',
#     'small': 'https://th.wallhaven.cc/small/vq/vqw6xl.jpg'}},
#   {'id': '2yrqgx',
#    'url': 'https://wallhaven.cc/w/2yrqgx',
#    'short_url': 'https://whvn.cc/2yrqgx',
#    'views': 85,
#    'favorites': 1,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 1920,
#    'dimension_y': 1080,
#    'resolution': '1920x1080',
#    'ratio': '1.78',
#    'file_size': 3413277,
#    'file_type': 'image/png',
#    'created_at': '2025-02-17 10:16:31',
#    'colors': ['#999999', '#424153', '#000000', '#abbcda', '#336600'],
#    'path': 'https://w.wallhaven.cc/full/2y/wallhaven-2yrqgx.png',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/2y/2yrqgx.jpg',
#     'original': 'https://th.wallhaven.cc/orig/2y/2yrqgx.jpg',
#     'small': 'https://th.wallhaven.cc/small/2y/2yrqgx.jpg'}},
#   {'id': 'rrk9vw',
#    'url': 'https://wallhaven.cc/w/rrk9vw',
#    'short_url': 'https://whvn.cc/rrk9vw',
#    'views': 253,
#    'favorites': 18,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2560,
#    'dimension_y': 1707,
#    'resolution': '2560x1707',
#    'ratio': '1.5',
#    'file_size': 1284030,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 07:34:21',
#    'colors': ['#666600', '#663300', '#000000', '#996633', '#999900'],
#    'path': 'https://w.wallhaven.cc/full/rr/wallhaven-rrk9vw.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/rr/rrk9vw.jpg',
#     'original': 'https://th.wallhaven.cc/orig/rr/rrk9vw.jpg',
#     'small': 'https://th.wallhaven.cc/small/rr/rrk9vw.jpg'}},
#   {'id': 'p9q1z3',
#    'url': 'https://wallhaven.cc/w/p9q1z3',
#    'short_url': 'https://whvn.cc/p9q1z3',
#    'views': 571,
#    'favorites': 36,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1440,
#    'dimension_y': 2148,
#    'resolution': '1440x2148',
#    'ratio': '0.67',
#    'file_size': 577001,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-16 19:26:28',
#    'colors': ['#424153', '#996633', '#cccccc', '#999999', '#663300'],
#    'path': 'https://w.wallhaven.cc/full/p9/wallhaven-p9q1z3.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/p9/p9q1z3.jpg',
#     'original': 'https://th.wallhaven.cc/orig/p9/p9q1z3.jpg',
#     'small': 'https://th.wallhaven.cc/small/p9/p9q1z3.jpg'}},
#   {'id': '7pyvky',
#    'url': 'https://wallhaven.cc/w/7pyvky',
#    'short_url': 'https://whvn.cc/7pyvky',
#    'views': 465,
#    'favorites': 32,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'people',
#    'dimension_x': 1080,
#    'dimension_y': 1349,
#    'resolution': '1080x1349',
#    'ratio': '0.8',
#    'file_size': 144734,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-16 19:26:28',
#    'colors': ['#cccccc', '#424153', '#999999', '#abbcda', '#996633'],
#    'path': 'https://w.wallhaven.cc/full/7p/wallhaven-7pyvky.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/7p/7pyvky.jpg',
#     'original': 'https://th.wallhaven.cc/orig/7p/7pyvky.jpg',
#     'small': 'https://th.wallhaven.cc/small/7p/7pyvky.jpg'}},
#   {'id': 'exjg1k',
#    'url': 'https://wallhaven.cc/w/exjg1k',
#    'short_url': 'https://whvn.cc/exjg1k',
#    'views': 332,
#    'favorites': 4,
#    'source': 'https://www.artstation.com/bynde',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 3000,
#    'dimension_y': 1800,
#    'resolution': '3000x1800',
#    'ratio': '1.67',
#    'file_size': 1279036,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-16 17:41:14',
#    'colors': ['#999999', '#000000', '#cccccc', '#abbcda', '#424153'],
#    'path': 'https://w.wallhaven.cc/full/ex/wallhaven-exjg1k.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/ex/exjg1k.jpg',
#     'original': 'https://th.wallhaven.cc/orig/ex/exjg1k.jpg',
#     'small': 'https://th.wallhaven.cc/small/ex/exjg1k.jpg'}},
#   {'id': 'qz1k8d',
#    'url': 'https://wallhaven.cc/w/qz1k8d',
#    'short_url': 'https://whvn.cc/qz1k8d',
#    'views': 657,
#    'favorites': 42,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1920,
#    'dimension_y': 1080,
#    'resolution': '1920x1080',
#    'ratio': '1.78',
#    'file_size': 919282,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-16 16:22:03',
#    'colors': ['#996633', '#000000', '#663300', '#999999', '#424153'],
#    'path': 'https://w.wallhaven.cc/full/qz/wallhaven-qz1k8d.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/qz/qz1k8d.jpg',
#     'original': 'https://th.wallhaven.cc/orig/qz/qz1k8d.jpg',
#     'small': 'https://th.wallhaven.cc/small/qz/qz1k8d.jpg'}},
#   {'id': '3ldv39',
#    'url': 'https://wallhaven.cc/w/3ldv39',
#    'short_url': 'https://whvn.cc/3ldv39',
#    'views': 456,
#    'favorites': 32,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1920,
#    'dimension_y': 1280,
#    'resolution': '1920x1280',
#    'ratio': '1.5',
#    'file_size': 1044197,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-16 05:47:12',
#    'colors': ['#996633', '#cccccc', '#ffffff', '#999999', '#424153'],
#    'path': 'https://w.wallhaven.cc/full/3l/wallhaven-3ldv39.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/3l/3ldv39.jpg',
#     'original': 'https://th.wallhaven.cc/orig/3l/3ldv39.jpg',
#     'small': 'https://th.wallhaven.cc/small/3l/3ldv39.jpg'}},
#   {'id': '2yrvem',
#    'url': 'https://wallhaven.cc/w/2yrvem',
#    'short_url': 'https://whvn.cc/2yrvem',
#    'views': 765,
#    'favorites': 36,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2000,
#    'dimension_y': 3000,
#    'resolution': '2000x3000',
#    'ratio': '0.67',
#    'file_size': 1165544,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-15 21:17:32',
#    'colors': ['#999999', '#424153', '#66cccc', '#ffffff', '#e7d8b1'],
#    'path': 'https://w.wallhaven.cc/full/2y/wallhaven-2yrvem.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/2y/2yrvem.jpg',
#     'original': 'https://th.wallhaven.cc/orig/2y/2yrvem.jpg',
#     'small': 'https://th.wallhaven.cc/small/2y/2yrvem.jpg'}},
#   {'id': 'm3x5q1',
#    'url': 'https://wallhaven.cc/w/m3x5q1',
#    'short_url': 'https://whvn.cc/m3x5q1',
#    'views': 672,
#    'favorites': 46,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 4000,
#    'dimension_y': 6000,
#    'resolution': '4000x6000',
#    'ratio': '0.67',
#    'file_size': 10888168,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-15 18:49:08',
#    'colors': ['#999999', '#424153', '#000000', '#cccccc', '#336600'],
#    'path': 'https://w.wallhaven.cc/full/m3/wallhaven-m3x5q1.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/m3/m3x5q1.jpg',
#     'original': 'https://th.wallhaven.cc/orig/m3/m3x5q1.jpg',
#     'small': 'https://th.wallhaven.cc/small/m3/m3x5q1.jpg'}},
#   {'id': 'o5z8k9',
#    'url': 'https://wallhaven.cc/w/o5z8k9',
#    'short_url': 'https://whvn.cc/o5z8k9',
#    'views': 599,
#    'favorites': 51,
#    'source': 'https://twitter.com/goldgoofy357/status/1890343715627008160',
#    'purity': 'sketchy',
#    'category': 'anime',
#    'dimension_x': 3751,
#    'dimension_y': 2500,
#    'resolution': '3751x2500',
#    'ratio': '1.5',
#    'file_size': 725565,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-15 18:26:25',
#    'colors': ['#ffffff', '#e7d8b1', '#999999', '#abbcda', '#66cccc'],
#    'path': 'https://w.wallhaven.cc/full/o5/wallhaven-o5z8k9.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/o5/o5z8k9.jpg',
#     'original': 'https://th.wallhaven.cc/orig/o5/o5z8k9.jpg',
#     'small': 'https://th.wallhaven.cc/small/o5/o5z8k9.jpg'}},
#   {'id': '9djpjk',
#    'url': 'https://wallhaven.cc/w/9djpjk',
#    'short_url': 'https://whvn.cc/9djpjk',
#    'views': 844,
#    'favorites': 55,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2160,
#    'dimension_y': 1440,
#    'resolution': '2160x1440',
#    'ratio': '1.5',
#    'file_size': 1024434,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-15 17:40:33',
#    'colors': ['#424153', '#000000', '#663300', '#abbcda', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/9d/wallhaven-9djpjk.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/9d/9djpjk.jpg',
#     'original': 'https://th.wallhaven.cc/orig/9d/9djpjk.jpg',
#     'small': 'https://th.wallhaven.cc/small/9d/9djpjk.jpg'}},
#   {'id': '6dv6vq',
#    'url': 'https://wallhaven.cc/w/6dv6vq',
#    'short_url': 'https://whvn.cc/6dv6vq',
#    'views': 1196,
#    'favorites': 48,
#    'source': 'https://twitter.com/jvn_artwork/status/1889705055072428278',
#    'purity': 'sfw',
#    'category': 'anime',
#    'dimension_x': 3314,
#    'dimension_y': 4096,
#    'resolution': '3314x4096',
#    'ratio': '0.81',
#    'file_size': 3327528,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-15 16:46:33',
#    'colors': ['#000000', '#999999', '#424153', '#996633', '#663300'],
#    'path': 'https://w.wallhaven.cc/full/6d/wallhaven-6dv6vq.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/6d/6dv6vq.jpg',
#     'original': 'https://th.wallhaven.cc/orig/6d/6dv6vq.jpg',
#     'small': 'https://th.wallhaven.cc/small/6d/6dv6vq.jpg'}}],
#  'meta': {'current_page': 1,
#   'last_page': 5399,
#   'per_page': '24',
#   'total': 129566,
#   'query': 'nature',
#   'seed': None}}

# %%
get_wallhaven_photos(query='nature')
# Out:
# (['https://w.wallhaven.cc/full/gp/wallhaven-gpoe2d.jpg',
#   'https://w.wallhaven.cc/full/jx/wallhaven-jxmzvy.jpg',
#   'https://w.wallhaven.cc/full/d6/wallhaven-d6l7el.jpg',
#   'https://w.wallhaven.cc/full/qz/wallhaven-qz1ygq.jpg',
#   'https://w.wallhaven.cc/full/6d/wallhaven-6dvr2w.jpg',
#   'https://w.wallhaven.cc/full/m3/wallhaven-m3xkwy.jpg',
#   'https://w.wallhaven.cc/full/p9/wallhaven-p9qdjm.jpg',
#   'https://w.wallhaven.cc/full/7p/wallhaven-7py5we.jpg',
#   'https://w.wallhaven.cc/full/ex/wallhaven-exjmer.jpg',
#   'https://w.wallhaven.cc/full/d6/wallhaven-d6l75j.jpg'],
#  [{'id': 'gpoe2d',
#    'url': 'https://wallhaven.cc/w/gpoe2d',
#    'short_url': 'https://whvn.cc/gpoe2d',
#    'views': 6,
#    'favorites': 3,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1500,
#    'dimension_y': 1000,
#    'resolution': '1500x1000',
#    'ratio': '1.5',
#    'file_size': 419876,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 16:36:50',
#    'colors': ['#cccccc', '#999999', '#0099cc', '#e7d8b1', '#abbcda'],
#    'path': 'https://w.wallhaven.cc/full/gp/wallhaven-gpoe2d.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/gp/gpoe2d.jpg',
#     'original': 'https://th.wallhaven.cc/orig/gp/gpoe2d.jpg',
#     'small': 'https://th.wallhaven.cc/small/gp/gpoe2d.jpg'}},
#   {'id': 'jxmzvy',
#    'url': 'https://wallhaven.cc/w/jxmzvy',
#    'short_url': 'https://whvn.cc/jxmzvy',
#    'views': 5,
#    'favorites': 5,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2996,
#    'dimension_y': 1876,
#    'resolution': '2996x1876',
#    'ratio': '1.6',
#    'file_size': 2209803,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 16:36:50',
#    'colors': ['#66cccc', '#0099cc', '#abbcda', '#ea4c88', '#cccccc'],
#    'path': 'https://w.wallhaven.cc/full/jx/wallhaven-jxmzvy.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/jx/jxmzvy.jpg',
#     'original': 'https://th.wallhaven.cc/orig/jx/jxmzvy.jpg',
#     'small': 'https://th.wallhaven.cc/small/jx/jxmzvy.jpg'}},
#   {'id': 'd6l7el',
#    'url': 'https://wallhaven.cc/w/d6l7el',
#    'short_url': 'https://whvn.cc/d6l7el',
#    'views': 15,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 6144,
#    'dimension_y': 3456,
#    'resolution': '6144x3456',
#    'ratio': '1.78',
#    'file_size': 14729796,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 16:05:26',
#    'colors': ['#424153', '#663399', '#000000', '#333399', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/d6/wallhaven-d6l7el.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/d6/d6l7el.jpg',
#     'original': 'https://th.wallhaven.cc/orig/d6/d6l7el.jpg',
#     'small': 'https://th.wallhaven.cc/small/d6/d6l7el.jpg'}},
#   {'id': 'qz1ygq',
#    'url': 'https://wallhaven.cc/w/qz1ygq',
#    'short_url': 'https://whvn.cc/qz1ygq',
#    'views': 11,
#    'favorites': 3,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 5120,
#    'dimension_y': 2880,
#    'resolution': '5120x2880',
#    'ratio': '1.78',
#    'file_size': 10428473,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:59:33',
#    'colors': ['#0066cc', '#000000', '#424153', '#333399', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/qz/wallhaven-qz1ygq.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/qz/qz1ygq.jpg',
#     'original': 'https://th.wallhaven.cc/orig/qz/qz1ygq.jpg',
#     'small': 'https://th.wallhaven.cc/small/qz/qz1ygq.jpg'}},
#   {'id': '6dvr2w',
#    'url': 'https://wallhaven.cc/w/6dvr2w',
#    'short_url': 'https://whvn.cc/6dvr2w',
#    'views': 5,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 6144,
#    'dimension_y': 3456,
#    'resolution': '6144x3456',
#    'ratio': '1.78',
#    'file_size': 10911800,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#999999', '#abbcda', '#cccccc', '#0099cc'],
#    'path': 'https://w.wallhaven.cc/full/6d/wallhaven-6dvr2w.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/6d/6dvr2w.jpg',
#     'original': 'https://th.wallhaven.cc/orig/6d/6dvr2w.jpg',
#     'small': 'https://th.wallhaven.cc/small/6d/6dvr2w.jpg'}},
#   {'id': 'm3xkwy',
#    'url': 'https://wallhaven.cc/w/m3xkwy',
#    'short_url': 'https://whvn.cc/m3xkwy',
#    'views': 10,
#    'favorites': 6,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 8838,
#    'dimension_y': 4972,
#    'resolution': '8838x4972',
#    'ratio': '1.78',
#    'file_size': 15420648,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#333399', '#000000', '#336600', '#0066cc'],
#    'path': 'https://w.wallhaven.cc/full/m3/wallhaven-m3xkwy.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/m3/m3xkwy.jpg',
#     'original': 'https://th.wallhaven.cc/orig/m3/m3xkwy.jpg',
#     'small': 'https://th.wallhaven.cc/small/m3/m3xkwy.jpg'}},
#   {'id': 'p9qdjm',
#    'url': 'https://wallhaven.cc/w/p9qdjm',
#    'short_url': 'https://whvn.cc/p9qdjm',
#    'views': 12,
#    'favorites': 8,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 8256,
#    'dimension_y': 4818,
#    'resolution': '8256x4818',
#    'ratio': '1.71',
#    'file_size': 16043344,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#996633', '#0066cc', '#ff6600', '#000000'],
#    'path': 'https://w.wallhaven.cc/full/p9/wallhaven-p9qdjm.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/p9/p9qdjm.jpg',
#     'original': 'https://th.wallhaven.cc/orig/p9/p9qdjm.jpg',
#     'small': 'https://th.wallhaven.cc/small/p9/p9qdjm.jpg'}},
#   {'id': '7py5we',
#    'url': 'https://wallhaven.cc/w/7py5we',
#    'short_url': 'https://whvn.cc/7py5we',
#    'views': 15,
#    'favorites': 8,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 6048,
#    'dimension_y': 3590,
#    'resolution': '6048x3590',
#    'ratio': '1.68',
#    'file_size': 14474225,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#000000', '#333399', '#999999', '#663399'],
#    'path': 'https://w.wallhaven.cc/full/7p/wallhaven-7py5we.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/7p/7py5we.jpg',
#     'original': 'https://th.wallhaven.cc/orig/7p/7py5we.jpg',
#     'small': 'https://th.wallhaven.cc/small/7p/7py5we.jpg'}},
#   {'id': 'exjmer',
#    'url': 'https://wallhaven.cc/w/exjmer',
#    'short_url': 'https://whvn.cc/exjmer',
#    'views': 9,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 11574,
#    'dimension_y': 6000,
#    'resolution': '11574x6000',
#    'ratio': '1.93',
#    'file_size': 16333913,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 15:56:00',
#    'colors': ['#424153', '#000000', '#999999', '#77cc33', '#663399'],
#    'path': 'https://w.wallhaven.cc/full/ex/wallhaven-exjmer.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/ex/exjmer.jpg',
#     'original': 'https://th.wallhaven.cc/orig/ex/exjmer.jpg',
#     'small': 'https://th.wallhaven.cc/small/ex/exjmer.jpg'}},
#   {'id': 'd6l75j',
#    'url': 'https://wallhaven.cc/w/d6l75j',
#    'short_url': 'https://whvn.cc/d6l75j',
#    'views': 135,
#    'favorites': 9,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 2000,
#    'dimension_y': 1516,
#    'resolution': '2000x1516',
#    'ratio': '1.32',
#    'file_size': 654578,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 11:07:06',
#    'colors': ['#999999', '#424153', '#996633', '#cccccc', '#000000'],
#    'path': 'https://w.wallhaven.cc/full/d6/wallhaven-d6l75j.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/d6/d6l75j.jpg',
#     'original': 'https://th.wallhaven.cc/orig/d6/d6l75j.jpg',
#     'small': 'https://th.wallhaven.cc/small/d6/d6l75j.jpg'}}])

# %%
get_wallhaven_photos(photo_id='gpoe2d')
# Out:
# (['https://w.wallhaven.cc/full/gp/wallhaven-gpoe2d.jpg'],
#  [{'id': 'gpoe2d',
#    'url': 'https://wallhaven.cc/w/gpoe2d',
#    'short_url': 'https://whvn.cc/gpoe2d',
#    'uploader': {'username': 'Rkomy',
#     'group': 'User',
#     'avatar': {'200px': 'https://wallhaven.cc/images/user/avatar/200/default-avatar.jpg',
#      '128px': 'https://wallhaven.cc/images/user/avatar/128/default-avatar.jpg',
#      '32px': 'https://wallhaven.cc/images/user/avatar/32/default-avatar.jpg',
#      '20px': 'https://wallhaven.cc/images/user/avatar/20/default-avatar.jpg'}},
#    'views': 5,
#    'favorites': 3,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1500,
#    'dimension_y': 1000,
#    'resolution': '1500x1000',
#    'ratio': '1.5',
#    'file_size': 419876,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-17 16:36:50',
#    'colors': ['#cccccc', '#999999', '#0099cc', '#e7d8b1', '#abbcda'],
#    'path': 'https://w.wallhaven.cc/full/gp/wallhaven-gpoe2d.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/gp/gpoe2d.jpg',
#     'original': 'https://th.wallhaven.cc/orig/gp/gpoe2d.jpg',
#     'small': 'https://th.wallhaven.cc/small/gp/gpoe2d.jpg'},
#    'tags': [{'id': 101060,
#      'name': 'Kyler Quinn',
#      'alias': '',
#      'category_id': 52,
#      'category': 'Pornstars',
#      'purity': 'nsfw',
#      'created_at': '2020-06-22 16:27:38'},
#     {'id': 222,
#      'name': 'women',
#      'alias': "AI Ladies, Babes, Beautifull Girl, cute girl, fantasy woman, female, girl, girl's, girls, group of women, healthy women, hot girls, ladies, lady, mujer, Sexy Woman, teen babe, weather girls, womam, woman, Woomen, young girl",
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-02-11 03:40:00'},
#     {'id': 182,
#      'name': 'brunette',
#      'alias': 'anime girls brunette, brow hair, brown hair, brunet, brunett, Brunettes, brunettes, Burnette',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-02-09 00:51:25'},
#     {'id': 188,
#      'name': 'blue eyes',
#      'alias': 'azure eyes, blue eye, sky blue eyes',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-02-09 00:52:17'},
#     {'id': 6625,
#      'name': 'hips',
#      'alias': 'hip',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-09-20 14:53:51'},
#     {'id': 2196,
#      'name': 'belly',
#      'alias': 'abdomen, abdomens, bellies, exposed midriff, stomach, stomachs, tummies, tummy',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sketchy',
#      'created_at': '2014-05-23 17:54:35'},
#     {'id': 45274,
#      'name': 'belly button',
#      'alias': 'navel, navels',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sketchy',
#      'created_at': '2016-04-27 05:12:03'},
#     {'id': 274,
#      'name': 'legs',
#      'alias': 'long leg, long legs, sexy legs',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-02-11 04:10:39'},
#     {'id': 858,
#      'name': 'feet',
#      'alias': 'feet in the water, feets, foot, foots',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-03-24 03:21:18'},
#     {'id': 863,
#      'name': 'barefoot',
#      'alias': 'bare feet, barefeet, bare foot',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-03-24 03:30:17'},
#     {'id': 174,
#      'name': 'bikini',
#      'alias': 'bikini bottom, bikinis, bkini, two piece swimsuit, Women Bikini',
#      'category_id': 35,
#      'category': 'Clothing',
#      'purity': 'sketchy',
#      'created_at': '2014-02-09 00:50:37'},
#     {'id': 46360,
#      'name': 'red bikini',
#      'alias': 'red bikinis',
#      'category_id': 35,
#      'category': 'Clothing',
#      'purity': 'sketchy',
#      'created_at': '2016-05-20 01:36:41'},
#     {'id': 390,
#      'name': 'bra',
#      'alias': 'bras, brassiere',
#      'category_id': 35,
#      'category': 'Clothing',
#      'purity': 'sketchy',
#      'created_at': '2014-02-15 02:51:55'},
#     {'id': 45,
#      'name': 'panties',
#      'alias': 'Knickers, panchira, pantsu, panty, Undergarment, Underwear, Undies',
#      'category_id': 35,
#      'category': 'Clothing',
#      'purity': 'sketchy',
#      'created_at': '2014-02-02 19:31:03'},
#     {'id': 972,
#      'name': 'swimming pool',
#      'alias': 'in the pool, Pool, poolside, swimming pools',
#      'category_id': 6,
#      'category': 'Location',
#      'purity': 'sfw',
#      'created_at': '2014-03-26 12:27:27'},
#     {'id': 64017,
#      'name': 'Tushy',
#      'alias': 'Tushy.com',
#      'category_id': 37,
#      'category': 'Companies & Logos',
#      'purity': 'nsfw',
#      'created_at': '2017-07-20 19:28:52'},
#     {'id': 12540,
#      'name': 'red lipstick',
#      'alias': '',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-10-20 02:13:13'},
#     {'id': 1023,
#      'name': 'lipstick',
#      'alias': '',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-03-27 09:44:56'},
#     {'id': 21919,
#      'name': 'bare shoulders',
#      'alias': 'shoulder, shoulders',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2015-01-26 11:55:20'},
#     {'id': 355,
#      'name': 'pornstar',
#      'alias': 'porn star, porn stars, pornstars',
#      'category_id': 52,
#      'category': 'Pornstars',
#      'purity': 'nsfw',
#      'created_at': '2014-02-12 05:54:10'},
#     {'id': 66306,
#      'name': 'pointed toes',
#      'alias': 'pointy toes',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sketchy',
#      'created_at': '2017-09-15 00:44:32'},
#     {'id': 872,
#      'name': 'women outdoors',
#      'alias': 'girls in nature, woman outdoors, women in nature',
#      'category_id': 7,
#      'category': 'People',
#      'purity': 'sfw',
#      'created_at': '2014-03-24 09:37:50'}]}])
