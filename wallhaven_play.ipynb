# %%
import requests

# %%
key = 't7Jx4fJDMjTyIdApWsmAxx5KDmeBskgj'
tag = 'nature'

response = requests.get(f'https://wallhaven.cc/api/v1/search?apikey={key}&q={tag}')

response.json()
# Out:
# {'data': [{'id': 'vqwe68',
#    'url': 'https://wallhaven.cc/w/vqwe68',
#    'short_url': 'https://whvn.cc/vqwe68',
#    'views': 60,
#    'favorites': 0,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 1920,
#    'dimension_y': 1080,
#    'resolution': '1920x1080',
#    'ratio': '1.78',
#    'file_size': 2296568,
#    'file_type': 'image/png',
#    'created_at': '2025-02-04 23:27:18',
#    'colors': ['#000000', '#663399', '#333399', '#424153', '#abbcda'],
#    'path': 'https://w.wallhaven.cc/full/vq/wallhaven-vqwe68.png',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/vq/vqwe68.jpg',
#     'original': 'https://th.wallhaven.cc/orig/vq/vqwe68.jpg',
#     'small': 'https://th.wallhaven.cc/small/vq/vqwe68.jpg'}},
#   {'id': '2yr2qm',
#    'url': 'https://wallhaven.cc/w/2yr2qm',
#    'short_url': 'https://whvn.cc/2yr2qm',
#    'views': 42,
#    'favorites': 1,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 1920,
#    'dimension_y': 1080,
#    'resolution': '1920x1080',
#    'ratio': '1.78',
#    'file_size': 2001110,
#    'file_type': 'image/png',
#    'created_at': '2025-02-04 23:27:17',
#    'colors': ['#000000', '#333399', '#66cccc', '#663399', '#0066cc'],
#    'path': 'https://w.wallhaven.cc/full/2y/wallhaven-2yr2qm.png',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/2y/2yr2qm.jpg',
#     'original': 'https://th.wallhaven.cc/orig/2y/2yr2qm.jpg',
#     'small': 'https://th.wallhaven.cc/small/2y/2yr2qm.jpg'}},
#   {'id': 'we2x77',
#    'url': 'https://wallhaven.cc/w/we2x77',
#    'short_url': 'https://whvn.cc/we2x77',
#    'views': 62,
#    'favorites': 1,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 1920,
#    'dimension_y': 1080,
#    'resolution': '1920x1080',
#    'ratio': '1.78',
#    'file_size': 1775531,
#    'file_type': 'image/png',
#    'created_at': '2025-02-04 23:27:17',
#    'colors': ['#000000', '#424153', '#996633', '#663300', '#cc6633'],
#    'path': 'https://w.wallhaven.cc/full/we/wallhaven-we2x77.png',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/we/we2x77.jpg',
#     'original': 'https://th.wallhaven.cc/orig/we/we2x77.jpg',
#     'small': 'https://th.wallhaven.cc/small/we/we2x77.jpg'}},
#   {'id': 'zyl9ev',
#    'url': 'https://wallhaven.cc/w/zyl9ev',
#    'short_url': 'https://whvn.cc/zyl9ev',
#    'views': 140,
#    'favorites': 16,
#    'source': 'https://www.pixiv.net/artworks/126801814',
#    'purity': 'sketchy',
#    'category': 'anime',
#    'dimension_x': 4000,
#    'dimension_y': 5000,
#    'resolution': '4000x5000',
#    'ratio': '0.8',
#    'file_size': 19637180,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-04 22:13:31',
#    'colors': ['#abbcda', '#999999', '#424153', '#000000', '#cccccc'],
#    'path': 'https://w.wallhaven.cc/full/zy/wallhaven-zyl9ev.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/zy/zyl9ev.jpg',
#     'original': 'https://th.wallhaven.cc/orig/zy/zyl9ev.jpg',
#     'small': 'https://th.wallhaven.cc/small/zy/zyl9ev.jpg'}},
#   {'id': 'x6v9md',
#    'url': 'https://wallhaven.cc/w/x6v9md',
#    'short_url': 'https://whvn.cc/x6v9md',
#    'views': 127,
#    'favorites': 8,
#    'source': 'https://www.pixiv.net/artworks/116887967',
#    'purity': 'sfw',
#    'category': 'anime',
#    'dimension_x': 3500,
#    'dimension_y': 1618,
#    'resolution': '3500x1618',
#    'ratio': '2.16',
#    'file_size': 4849983,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-04 21:49:52',
#    'colors': ['#cccccc', '#999999', '#424153', '#abbcda', '#333399'],
#    'path': 'https://w.wallhaven.cc/full/x6/wallhaven-x6v9md.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/x6/x6v9md.jpg',
#     'original': 'https://th.wallhaven.cc/orig/x6/x6v9md.jpg',
#     'small': 'https://th.wallhaven.cc/small/x6/x6v9md.jpg'}},
#   {'id': 'p9qgdj',
#    'url': 'https://wallhaven.cc/w/p9qgdj',
#    'short_url': 'https://whvn.cc/p9qgdj',
#    'views': 152,
#    'favorites': 5,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 3840,
#    'dimension_y': 2160,
#    'resolution': '3840x2160',
#    'ratio': '1.78',
#    'file_size': 3700188,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-04 21:32:09',
#    'colors': ['#424153', '#000000', '#333399', '#663300', '#663399'],
#    'path': 'https://w.wallhaven.cc/full/p9/wallhaven-p9qgdj.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/p9/p9qgdj.jpg',
#     'original': 'https://th.wallhaven.cc/orig/p9/p9qgdj.jpg',
#     'small': 'https://th.wallhaven.cc/small/p9/p9qgdj.jpg'}},
#   {'id': 'yxy967',
#    'url': 'https://wallhaven.cc/w/yxy967',
#    'short_url': 'https://whvn.cc/yxy967',
#    'views': 133,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 8256,
#    'dimension_y': 5951,
#    'resolution': '8256x5951',
#    'ratio': '1.39',
#    'file_size': 14835681,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-04 19:17:25',
#    'colors': ['#424153', '#333399', '#000000', '#999999', '#663399'],
#    'path': 'https://w.wallhaven.cc/full/yx/wallhaven-yxy967.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/yx/yxy967.jpg',
#     'original': 'https://th.wallhaven.cc/orig/yx/yxy967.jpg',
#     'small': 'https://th.wallhaven.cc/small/yx/yxy967.jpg'}},
#   {'id': '3ld2gy',
#    'url': 'https://wallhaven.cc/w/3ld2gy',
#    'short_url': 'https://whvn.cc/3ld2gy',
#    'views': 397,
#    'favorites': 22,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'people',
#    'dimension_x': 8640,
#    'dimension_y': 6480,
#    'resolution': '8640x6480',
#    'ratio': '1.33',
#    'file_size': 19250746,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-04 08:44:25',
#    'colors': ['#663300', '#996633', '#424153', '#999999', '#000000'],
#    'path': 'https://w.wallhaven.cc/full/3l/wallhaven-3ld2gy.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/3l/3ld2gy.jpg',
#     'original': 'https://th.wallhaven.cc/orig/3l/3ld2gy.jpg',
#     'small': 'https://th.wallhaven.cc/small/3l/3ld2gy.jpg'}},
#   {'id': 'rrk6yq',
#    'url': 'https://wallhaven.cc/w/rrk6yq',
#    'short_url': 'https://whvn.cc/rrk6yq',
#    'views': 389,
#    'favorites': 8,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 5000,
#    'dimension_y': 4000,
#    'resolution': '5000x4000',
#    'ratio': '1.25',
#    'file_size': 2622884,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 21:37:53',
#    'colors': ['#999999', '#424153', '#996633', '#ffffff', '#abbcda'],
#    'path': 'https://w.wallhaven.cc/full/rr/wallhaven-rrk6yq.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/rr/rrk6yq.jpg',
#     'original': 'https://th.wallhaven.cc/orig/rr/rrk6yq.jpg',
#     'small': 'https://th.wallhaven.cc/small/rr/rrk6yq.jpg'}},
#   {'id': 'kxpd17',
#    'url': 'https://wallhaven.cc/w/kxpd17',
#    'short_url': 'https://whvn.cc/kxpd17',
#    'views': 135,
#    'favorites': 2,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 2048,
#    'dimension_y': 1638,
#    'resolution': '2048x1638',
#    'ratio': '1.25',
#    'file_size': 1235203,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 21:34:05',
#    'colors': ['#999999', '#424153', '#abbcda', '#000000', '#cccccc'],
#    'path': 'https://w.wallhaven.cc/full/kx/wallhaven-kxpd17.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/kx/kxpd17.jpg',
#     'original': 'https://th.wallhaven.cc/orig/kx/kxpd17.jpg',
#     'small': 'https://th.wallhaven.cc/small/kx/kxpd17.jpg'}},
#   {'id': '1p92d3',
#    'url': 'https://wallhaven.cc/w/1p92d3',
#    'short_url': 'https://whvn.cc/1p92d3',
#    'views': 137,
#    'favorites': 4,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 2048,
#    'dimension_y': 1365,
#    'resolution': '2048x1365',
#    'ratio': '1.5',
#    'file_size': 1606975,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 21:30:34',
#    'colors': ['#cccccc', '#999999', '#424153', '#ffffff', '#abbcda'],
#    'path': 'https://w.wallhaven.cc/full/1p/wallhaven-1p92d3.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/1p/1p92d3.jpg',
#     'original': 'https://th.wallhaven.cc/orig/1p/1p92d3.jpg',
#     'small': 'https://th.wallhaven.cc/small/1p/1p92d3.jpg'}},
#   {'id': 'zyl98w',
#    'url': 'https://wallhaven.cc/w/zyl98w',
#    'short_url': 'https://whvn.cc/zyl98w',
#    'views': 402,
#    'favorites': 13,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 5120,
#    'dimension_y': 2880,
#    'resolution': '5120x2880',
#    'ratio': '1.78',
#    'file_size': 6480822,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 15:09:07',
#    'colors': ['#663300', '#000000', '#424153', '#996633', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/zy/wallhaven-zyl98w.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/zy/zyl98w.jpg',
#     'original': 'https://th.wallhaven.cc/orig/zy/zyl98w.jpg',
#     'small': 'https://th.wallhaven.cc/small/zy/zyl98w.jpg'}},
#   {'id': 'qz1o27',
#    'url': 'https://wallhaven.cc/w/qz1o27',
#    'short_url': 'https://whvn.cc/qz1o27',
#    'views': 545,
#    'favorites': 24,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 5120,
#    'dimension_y': 2880,
#    'resolution': '5120x2880',
#    'ratio': '1.78',
#    'file_size': 7034118,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 15:09:07',
#    'colors': ['#424153', '#333399', '#000000', '#abbcda', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/qz/wallhaven-qz1o27.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/qz/qz1o27.jpg',
#     'original': 'https://th.wallhaven.cc/orig/qz/qz1o27.jpg',
#     'small': 'https://th.wallhaven.cc/small/qz/qz1o27.jpg'}},
#   {'id': '9djgdx',
#    'url': 'https://wallhaven.cc/w/9djgdx',
#    'short_url': 'https://whvn.cc/9djgdx',
#    'views': 704,
#    'favorites': 29,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 5120,
#    'dimension_y': 2880,
#    'resolution': '5120x2880',
#    'ratio': '1.78',
#    'file_size': 11897150,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 15:09:07',
#    'colors': ['#424153', '#000000', '#abbcda', '#ffffff', '#999999'],
#    'path': 'https://w.wallhaven.cc/full/9d/wallhaven-9djgdx.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/9d/9djgdx.jpg',
#     'original': 'https://th.wallhaven.cc/orig/9d/9djgdx.jpg',
#     'small': 'https://th.wallhaven.cc/small/9d/9djgdx.jpg'}},
#   {'id': '1p92k9',
#    'url': 'https://wallhaven.cc/w/1p92k9',
#    'short_url': 'https://whvn.cc/1p92k9',
#    'views': 402,
#    'favorites': 12,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 5120,
#    'dimension_y': 2880,
#    'resolution': '5120x2880',
#    'ratio': '1.78',
#    'file_size': 5117886,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 15:09:07',
#    'colors': ['#000000', '#424153', '#999999', '#cccccc', '#abbcda'],
#    'path': 'https://w.wallhaven.cc/full/1p/wallhaven-1p92k9.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/1p/1p92k9.jpg',
#     'original': 'https://th.wallhaven.cc/orig/1p/1p92k9.jpg',
#     'small': 'https://th.wallhaven.cc/small/1p/1p92k9.jpg'}},
#   {'id': 'kxpd7m',
#    'url': 'https://wallhaven.cc/w/kxpd7m',
#    'short_url': 'https://whvn.cc/kxpd7m',
#    'views': 663,
#    'favorites': 17,
#    'source': '',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 3840,
#    'dimension_y': 2160,
#    'resolution': '3840x2160',
#    'ratio': '1.78',
#    'file_size': 6112694,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 15:09:07',
#    'colors': ['#424153', '#abbcda', '#000000', '#999999', '#cccccc'],
#    'path': 'https://w.wallhaven.cc/full/kx/wallhaven-kxpd7m.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/kx/kxpd7m.jpg',
#     'original': 'https://th.wallhaven.cc/orig/kx/kxpd7m.jpg',
#     'small': 'https://th.wallhaven.cc/small/kx/kxpd7m.jpg'}},
#   {'id': 'kxplmq',
#    'url': 'https://wallhaven.cc/w/kxplmq',
#    'short_url': 'https://whvn.cc/kxplmq',
#    'views': 688,
#    'favorites': 21,
#    'source': 'https://www.artstation.com/somartist',
#    'purity': 'sfw',
#    'category': 'general',
#    'dimension_x': 3840,
#    'dimension_y': 2400,
#    'resolution': '3840x2400',
#    'ratio': '1.6',
#    'file_size': 1227621,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 09:43:12',
#    'colors': ['#000000', '#424153', '#999999', '#abbcda', '#663399'],
#    'path': 'https://w.wallhaven.cc/full/kx/wallhaven-kxplmq.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/kx/kxplmq.jpg',
#     'original': 'https://th.wallhaven.cc/orig/kx/kxplmq.jpg',
#     'small': 'https://th.wallhaven.cc/small/kx/kxplmq.jpg'}},
#   {'id': 'x6vdx3',
#    'url': 'https://wallhaven.cc/w/x6vdx3',
#    'short_url': 'https://whvn.cc/x6vdx3',
#    'views': 711,
#    'favorites': 46,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2999,
#    'dimension_y': 2000,
#    'resolution': '2999x2000',
#    'ratio': '1.5',
#    'file_size': 880750,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 09:12:33',
#    'colors': ['#000000', '#999999', '#996633', '#abbcda', '#424153'],
#    'path': 'https://w.wallhaven.cc/full/x6/wallhaven-x6vdx3.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/x6/x6vdx3.jpg',
#     'original': 'https://th.wallhaven.cc/orig/x6/x6vdx3.jpg',
#     'small': 'https://th.wallhaven.cc/small/x6/x6vdx3.jpg'}},
#   {'id': '85l921',
#    'url': 'https://wallhaven.cc/w/85l921',
#    'short_url': 'https://whvn.cc/85l921',
#    'views': 642,
#    'favorites': 34,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2999,
#    'dimension_y': 2000,
#    'resolution': '2999x2000',
#    'ratio': '1.5',
#    'file_size': 1322058,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 09:12:33',
#    'colors': ['#999999', '#424153', '#000000', '#abbcda', '#996633'],
#    'path': 'https://w.wallhaven.cc/full/85/wallhaven-85l921.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/85/85l921.jpg',
#     'original': 'https://th.wallhaven.cc/orig/85/85l921.jpg',
#     'small': 'https://th.wallhaven.cc/small/85/85l921.jpg'}},
#   {'id': 'm3xg8y',
#    'url': 'https://wallhaven.cc/w/m3xg8y',
#    'short_url': 'https://whvn.cc/m3xg8y',
#    'views': 807,
#    'favorites': 54,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2000,
#    'dimension_y': 2999,
#    'resolution': '2000x2999',
#    'ratio': '0.67',
#    'file_size': 1440459,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 09:03:29',
#    'colors': ['#999999', '#424153', '#abbcda', '#996633', '#cccccc'],
#    'path': 'https://w.wallhaven.cc/full/m3/wallhaven-m3xg8y.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/m3/m3xg8y.jpg',
#     'original': 'https://th.wallhaven.cc/orig/m3/m3xg8y.jpg',
#     'small': 'https://th.wallhaven.cc/small/m3/m3xg8y.jpg'}},
#   {'id': '7pyede',
#    'url': 'https://wallhaven.cc/w/7pyede',
#    'short_url': 'https://whvn.cc/7pyede',
#    'views': 470,
#    'favorites': 33,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2000,
#    'dimension_y': 2999,
#    'resolution': '2000x2999',
#    'ratio': '0.67',
#    'file_size': 1293206,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 09:03:29',
#    'colors': ['#999999', '#996633', '#424153', '#abbcda', '#663300'],
#    'path': 'https://w.wallhaven.cc/full/7p/wallhaven-7pyede.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/7p/7pyede.jpg',
#     'original': 'https://th.wallhaven.cc/orig/7p/7pyede.jpg',
#     'small': 'https://th.wallhaven.cc/small/7p/7pyede.jpg'}},
#   {'id': 'gpom3q',
#    'url': 'https://wallhaven.cc/w/gpom3q',
#    'short_url': 'https://whvn.cc/gpom3q',
#    'views': 456,
#    'favorites': 28,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 2000,
#    'dimension_y': 2999,
#    'resolution': '2000x2999',
#    'ratio': '0.67',
#    'file_size': 1014201,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 09:03:29',
#    'colors': ['#999999', '#996633', '#424153', '#000000', '#663300'],
#    'path': 'https://w.wallhaven.cc/full/gp/wallhaven-gpom3q.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/gp/gpom3q.jpg',
#     'original': 'https://th.wallhaven.cc/orig/gp/gpom3q.jpg',
#     'small': 'https://th.wallhaven.cc/small/gp/gpom3q.jpg'}},
#   {'id': 'yxy2zx',
#    'url': 'https://wallhaven.cc/w/yxy2zx',
#    'short_url': 'https://whvn.cc/yxy2zx',
#    'views': 539,
#    'favorites': 28,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1366,
#    'dimension_y': 2048,
#    'resolution': '1366x2048',
#    'ratio': '0.67',
#    'file_size': 896692,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 08:45:37',
#    'colors': ['#424153', '#000000', '#999999', '#996633', '#cccccc'],
#    'path': 'https://w.wallhaven.cc/full/yx/wallhaven-yxy2zx.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/yx/yxy2zx.jpg',
#     'original': 'https://th.wallhaven.cc/orig/yx/yxy2zx.jpg',
#     'small': 'https://th.wallhaven.cc/small/yx/yxy2zx.jpg'}},
#   {'id': '2yrovm',
#    'url': 'https://wallhaven.cc/w/2yrovm',
#    'short_url': 'https://whvn.cc/2yrovm',
#    'views': 607,
#    'favorites': 38,
#    'source': '',
#    'purity': 'sketchy',
#    'category': 'people',
#    'dimension_x': 1440,
#    'dimension_y': 2160,
#    'resolution': '1440x2160',
#    'ratio': '0.67',
#    'file_size': 602065,
#    'file_type': 'image/jpeg',
#    'created_at': '2025-02-03 05:23:59',
#    'colors': ['#000000', '#996633', '#424153', '#999999', '#663300'],
#    'path': 'https://w.wallhaven.cc/full/2y/wallhaven-2yrovm.jpg',
#    'thumbs': {'large': 'https://th.wallhaven.cc/lg/2y/2yrovm.jpg',
#     'original': 'https://th.wallhaven.cc/orig/2y/2yrovm.jpg',
#     'small': 'https://th.wallhaven.cc/small/2y/2yrovm.jpg'}}],
#  'meta': {'current_page': 1,
#   'last_page': 5391,
#   'per_page': '24',
#   'total': 129382,
#   'query': 'nature',
#   'seed': None}}
